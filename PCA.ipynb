# %% [markdown]
# ### pca
#
# * Dimentionality reduction means reduce the number number features into 1d,2d,3d
#
# * demintionality reduction use the pca to reduce the no of dimensions
#
# steps:
# *  scale the data
# * apply pca for scaling data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
d=load_breast_cancer()
df=pd.DataFrame(d.data,columns=d.feature_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
scale_data=s.fit_transform(df)
scale_data
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %%
scale_data.shape
# Out:
# (569, 30)

# %%
from sklearn.decomposition import PCA
p=PCA(n_components=2)
p_data=p.fit_transform(scale_data)
p_data.shape
# Out:
# (569, 2)

# %%
pca_df=pd.DataFrame(p_data,columns=["one","two"])
pca_df.head()
x=pca_df['one']
y=pca_df['two']

# %%
plt.scatter(x,y,c='g')
plt.show()

# %%
# visuvalize the data
plt.scatter(p_data[0],p_data[1])
plt.show()

# %% [markdown]
# Outliers

# %%
df=pd.read_csv('advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
import seaborn as sns
sns.kdeplot(df['TV'])
sns.kdeplot(df['Radio'])
sns.kdeplot(df['Newspaper'])
sns.kdeplot(df['Sales'])

# %%
from sklearn.preprocessing import StandardScaler
s=StandardScaler()
scale_data=s.fit_transform(df)
scale_data
# Out:
# array([[ 9.69852266e-01,  9.81522472e-01,  1.77894547e+00,
#          1.32231867e+00],
#        [-1.19737623e+00,  1.08280781e+00,  6.69578760e-01,
#         -8.97514665e-01],
#        [-1.51615499e+00,  1.52846331e+00,  1.78354865e+00,
#         -5.93947713e-01],
#        [ 5.20496822e-02,  1.21785493e+00,  1.28640506e+00,
#          2.59834337e-01],
#        [ 3.94182198e-01, -8.41613655e-01,  1.28180188e+00,
#          5.25455420e-01],
#        [-1.61540845e+00,  1.73103399e+00,  2.04592999e+00,
#         -1.50464857e+00],
#        [-1.04557682e+00,  6.43904671e-01, -3.24708413e-01,
#         -6.31893582e-01],
#        [-3.13436589e-01, -2.47406325e-01, -8.72486994e-01,
#         -3.66272500e-01],
#        [-1.61657614e+00, -1.42906863e+00, -1.36042422e+00,
#         -1.95999899e+00],
#        [ 6.16042873e-01, -1.39530685e+00, -4.30581584e-01,
#          8.90779273e-02],
#        [-9.45155670e-01, -1.17923146e+00, -2.92486143e-01,
#         -4.80110107e-01],
# ...

# %%
df_s=pd.DataFrame(scale_data,columns=df.columns)
df_s
# Out:
#            TV     Radio  Newspaper     Sales
# 0    0.969852  0.981522   1.778945  1.322319
# 1   -1.197376  1.082808   0.669579 -0.897515
# 2   -1.516155  1.528463   1.783549 -0.593948
# 3    0.052050  1.217855   1.286405  0.259834
# 4    0.394182 -0.841614   1.281802  0.525455
# 5   -1.615408  1.731034   2.045930 -1.504649
# 6   -1.045577  0.643905  -0.324708 -0.631894
# 7   -0.313437 -0.247406  -0.872487 -0.366272
# 8   -1.616576 -1.429069  -1.360424 -1.959999
# 9    0.616043 -1.395307  -0.430582  0.089078
# 10  -0.945156 -1.179231  -0.292486 -0.480110
# 11   0.790028  0.049697  -1.222329  0.430591
# 12  -1.439088  0.799209   1.627040 -1.125190
# 13  -0.578502 -1.057689  -1.075027 -0.271408
# 14   0.666253  0.650657   0.711007  0.734158
# 15   0.564665  1.650006   1.028627  1.379237
# 16  -0.925305  0.900494   3.841171 -0.499083
# 17   1.568876  1.103065   1.162119  1.758696
# 18  -0.908957 -0.186635  -0.564074 -0.726758
# 19   0.003007  0.042945  -0.527248 -0.100651
# ...

# %%
import seaborn as sns
sns.kdeplot(df_s['TV'])
sns.kdeplot(df_s['Radio'])
sns.kdeplot(df_s['Newspaper'])
sns.kdeplot(df_s['Sales'])
